# %% [markdown]
# # Test connection to PostGRES Database

# %%
# !pip install psycopg2-binary

# %%
sql_list_tables = """
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public'
AND table_type = 'BASE TABLE';
"""

sql_create_tables = '''
CREATE TABLE IF NOT EXISTS public.usda_2022_branded_food_nutrients
(
    id integer NOT NULL,
    fdc_id integer,
    nutrient_id integer,
   amount numeric,
    data_points text COLLATE pg_catalog."default",
    derivation_id integer,
    min text COLLATE pg_catalog."default",
    max text COLLATE pg_catalog."default",
    median text COLLATE pg_catalog."default",
    footnote text COLLATE pg_catalog."default",
    min_year_acquired text COLLATE pg_catalog."default",
    CONSTRAINT usda_2022_branded_food_nutrition_pk PRIMARY KEY (id)
)

CREATE TABLE IF NOT EXISTS public.usda_2022_branded_food_nutrients
(
    id integer NOT NULL,
    fdc_id integer,
    nutrient_id integer,
    amount numeric,
    data_points text COLLATE pg_catalog."default",
    derivation_id integer,
    min text COLLATE pg_catalog."default",
    max text COLLATE pg_catalog."default",
    median text COLLATE pg_catalog."default",
    footnote text COLLATE pg_catalog."default",
    min_year_acquired text COLLATE pg_catalog."default",
    CONSTRAINT usda_2022_branded_food_nutrition_pk PRIMARY KEY (id)
)

CREATE TABLE IF NOT EXISTS public.usda_2022_food_branded_experimental
(
    fdc_id integer,
    data_type text COLLATE pg_catalog."default",
    description text COLLATE pg_catalog."default",
    food_category_id text COLLATE pg_catalog."default",
    publication_date text COLLATE pg_catalog."default"
)

CREATE TABLE IF NOT EXISTS public.usda_2022_food_calorie_conversion_factor
(
    food_nutrient_conversion_factor_id integer,
    protein_value text COLLATE pg_catalog."default",
    fat_value text COLLATE pg_catalog."default",
    carbohydrate_value text COLLATE pg_catalog."default"
)

CREATE TABLE IF NOT EXISTS public.usda_2022_food_portions
(
    id integer,
    fdc_id integer,
    seq_num integer,
    amount numeric,
    measure_unit_id integer,
    portion_description text COLLATE pg_catalog."default",
    modifier text COLLATE pg_catalog."default",
    gram_weight numeric,
    data_points text COLLATE pg_catalog."default",
    footnote text COLLATE pg_catalog."default",
    min_year_acquired text COLLATE pg_catalog."default"
)

CREATE TABLE IF NOT EXISTS public.usda_2022_food_protein_conversion_factor
(
    food_nutrient_conversion_factor_id integer,
    value numeric
)

CREATE TABLE IF NOT EXISTS public.usda_2022_nutrient_master
(
    id integer,
    name text COLLATE pg_catalog."default",
    unit_name text COLLATE pg_catalog."default",
    nutrient_nbr numeric,
    rank text COLLATE pg_catalog."default"
)
'''

# %%
import psycopg2
from psycopg2 import sql

# Define your connection string
connection_string = "postgresql://ndp-public:XKcBHaU1@awesome-hw.sdsc.edu:5432/nourish"

# Connect to the PostgreSQL database
try:
    connection = psycopg2.connect(connection_string)

    # Create a cursor object to interact with the database
    cursor = connection.cursor()

    # Execute a query (for example, check the PostgreSQL version)
    cursor.execute("SELECT version();")
    
    # Fetch and display the result
    db_version = cursor.fetchone()
    print(f"PostgreSQL version: {db_version}")

    # Query to list all tables in the current schema (public by default)
    print('\nTables:')
    cursor.execute(sql_list_tables)

    # Fetch all table names
    tables = cursor.fetchall()

    # Print the list of tables
    for table in tables:
        print(table[0])
    
    # Close the cursor and connection
    cursor.close()
    connection.close()

except Exception as error:
    print(f"Error connecting to PostgreSQL database: {error}")
# Out:
# PostgreSQL version: ('PostgreSQL 12.18 (Ubuntu 12.18-0ubuntu0.20.04.1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0, 64-bit',)
#
# Tables:
# ca_business
# spatial_ref_sys
# usda_2022_branded_food_nutrients
# usda_2022_branded_food_product
# usda_2022_food_branded_experimental
# usda_2022_food_calorie_conversion_factor
# usda_2022_food_portions
# usda_2022_food_protein_conversion_factor
# usda_2022_nutrient_master
